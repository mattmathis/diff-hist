# %% [markdown]
# <!-- GENERATED from diff-hist/tools/gen_public_docs.py by tools/gen_public_docs.py — edit the source, not here. -->
#
# # Differential Competition Reports
#
# **Internal use only — do not share.** These reports identify nearby M-Lab servers that outperform a given server to some client networks.

# %% [markdown]
# ## [Competition Report — minRTT](differential_competition_report_for_minrtt_internal_use_only.ipynb)
#
# Two dashboards — **Competition Reports for minRTT** and **for Throughput** —
# identify other nearby M-Lab servers that outperform your servers to some client
# networks. This can be useful when planning peering upgrades.
#
# [Full documentation →](https://annealing.mattmathis.net/differential-histograms/competition_reports)

# %% [markdown]
# ## [Competition Report — Throughput](differential_competition_report_for_throughput_internal_use_only.ipynb)
#
# Two dashboards — **Competition Reports for minRTT** and **for Throughput** —
# identify other nearby M-Lab servers that outperform your servers to some client
# networks. This can be useful when planning peering upgrades.
#
# [Full documentation →](https://annealing.mattmathis.net/differential-histograms/competition_reports)
